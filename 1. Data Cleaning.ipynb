# %%
import pandas as pd

# %%
data = pd.read_csv('CDKN2A main data.csv')
data
# Out:
#      GENE_NAME   ACCESSION_NUMBER   GENE_CDS_LENGTH   HGNC_ID  \
# 0       CDKN2A  ENST00000498124.1               504      1787
# 1       CDKN2A  ENST00000498124.1               504      1787
# 2       CDKN2A  ENST00000498124.1               504      1787
# 3       CDKN2A  ENST00000498124.1               504      1787
# 4       CDKN2A  ENST00000498124.1               504      1787
# ...        ...                ...               ...       ...
# 3711    CDKN2A  ENST00000498124.1               504      1787
# 3712    CDKN2A  ENST00000498124.1               504      1787
# 3713    CDKN2A  ENST00000498124.1               504      1787
# 3714    CDKN2A  ENST00000498124.1               504      1787
# 3715    CDKN2A  ENST00000498124.1               504      1787
#
#             SAMPLE_NAME   ID_SAMPLE   ID_TUMOUR               PRIMARY_SITE  \
# 0               2692607     2692607     2551579                    thyroid
# 1                902550      902550      820104                     pleura
# 2                S87946      943503      860138                     cervix
# 3                 ME024     1838446     1732547                       skin
# 4                S88227      943766      860401                   pancreas
# ...                 ...         ...         ...                        ...
# 3711  P-0009960-T01-IM5     2725787     2584608                       lung
# 3712    TCGA-85-7699-01     2195194     2063472                       lung
# 3713           GBM18-I1     2813453     2669845     central_nervous_system
# 3714             933237      933237      849894                   pancreas
# 3715            1170097     1170097     1082231  upper_aerodigestive_tract
#
#         SITE_SUBTYPE_1  SITE_SUBTYPE_2  ...  RESISTANCE_MUTATION  \
# 0                   NS              NS  ...                    -
# 1                   NS              NS  ...                    -
# 2                   NS              NS  ...                    -
# 3                trunk              NS  ...                    -
# 4                   NS              NS  ...                    -
# ...                ...             ...  ...                  ...
# 3711                NS              NS  ...                    -
# 3712                NS              NS  ...                    -
# 3713             brain              NS  ...                    -
# 3714  ampulla_of_Vater              NS  ...                    -
# 3715             mouth              NS  ...                    -
#
#         MUTATION_SOMATIC_STATUS  PUBMED_PMID  ID_STUDY           SAMPLE_TYPE  \
# 0     Variant of unknown origin   28351340.0       NaN         surgery-fixed
# 1     Variant of unknown origin   12117769.0       NaN  surgery fresh/frozen
# 2     Variant of unknown origin   10408854.0       NaN  surgery fresh/frozen
# 3     Variant of unknown origin   22817889.0       NaN                    NS
# 4     Variant of unknown origin   11753042.0       NaN         surgery - NOS
# ...                         ...          ...       ...                   ...
# 3711  Confirmed somatic variant   28481359.0       NaN         surgery-fixed
# 3712  Confirmed somatic variant          NaN     418.0                    NS
# 3713  Confirmed somatic variant   28263318.0       NaN  surgery fresh/frozen
# 3714  Confirmed somatic variant   15014024.0       NaN         surgery-fixed
# 3715  Confirmed somatic variant   19101490.0       NaN  surgery fresh/frozen
#
#       TUMOUR_ORIGIN   AGE                                HGVSP  \
# 0                NS   NaN  ENSP00000418915.1:p.Pro70GlnfsTer49
# 1           primary  62.0         ENSP00000418915.1:p.His83Gln
# 2                NS   NaN          ENSP00000418915.1:p.Gly150=
# 3           primary  44.0  ENSP00000418915.1:p.Arg87GlyfsTer59
# 4           primary   NaN  ENSP00000418915.1:p.Glu61AlafsTer55
# ...             ...   ...                                  ...
# 3711        primary   NaN        ENSP00000418915.1:p.His123Asn
# 3712             NS  73.0        ENSP00000418915.1:p.Trp110Ter
# 3713             NS  40.0         ENSP00000418915.1:p.Asp84Gly
# 3714        primary   NaN         ENSP00000418915.1:p.Glu69Val
# 3715        primary   NaN        ENSP00000418915.1:p.Leu130Pro
#
#                                     HGVSC                          HGVSG
# 0          ENST00000498124.1:c.209_210del       9:g.21971150_21971151del
# 1              ENST00000498124.1:c.249C>A                9:g.21971110G>T
# 2              ENST00000498124.1:c.450T>C                9:g.21970909A>G
# 3              ENST00000498124.1:c.259del                9:g.21971102del
# 4          ENST00000498124.1:c.177_187del       9:g.21971172_21971182del
# ...                                   ...                            ...
# 3711           ENST00000498124.1:c.367C>A                9:g.21970992G>T
# 3712           ENST00000498124.1:c.329G>A                9:g.21971030C>T
# 3713           ENST00000498124.1:c.251A>G                9:g.21971108T>C
# 3714  ENST00000498124.1:c.206_207delinsTA  9:g.21971152_21971153delinsTA
# 3715           ENST00000498124.1:c.389T>C                9:g.21970970A>G
#
# [3716 rows x 37 columns]

# %%
#filtering for mutation type missense substitution mutation

data = data[data[' MUTATION_DESCRIPTION'] == 'Substitution - Missense']
data.shape
# Out:
# (1386, 37)

# %%
#filter to remove mutation points where there is no genomic reference coordinate
#this is indicated by value 'null' in 'GRCH' column

data = data[data[' GRCH'] != 'null']
data.shape
# Out:
# (1386, 37)

# %%
#this is good, all our records has known substitution information

# %%
#now we remove all rows with insertion, duplication, inversion or deletion information

data = data[~data[' HGVSG'].str.contains('del|in|dup', case=False, na=False, regex=True)]
data.shape
# Out:
# (1351, 37)

# %% [markdown]
# We are done with all the filtering we need. We will now arrange the dataframe to better do our analyses. First, we build out our genomic level features.

# %%
columns_to_copy = ['GENE_NAME', ' ACCESSION_NUMBER', ' GENE_CDS_LENGTH', ' HGVSG', ' HGVSC', ' MUTATION_CDS']
new_df = data[columns_to_copy].copy()

# %%
#extract position of mutation
new_df['CDNA_POSITION'] = new_df[' MUTATION_CDS'].str.extract('(\d+)')
new_df['CDNA_POSITION'] = pd.to_numeric(new_df['CDNA_POSITION'], errors='coerce')

# %%
#extract mutation event, base and mutant alleles
new_df['MUTATION_EVENT'] = new_df[' MUTATION_CDS'].str[-3:]
new_df['BASE_ALLELE'] = new_df['MUTATION_EVENT'].str[0]
new_df['MUTANT_ALLELE'] = new_df['MUTATION_EVENT'].str[-1]

# %% [markdown]
# Now we get our proteomic level features.

# %%
aa_mapping = {
    'A': 'Ala',
    'R': 'Arg',
    'N': 'Asn',
    'D': 'Asp',
    'C': 'Cys',
    'Q': 'Gln',
    'E': 'Glu',
    'G': 'Gly',
    'H': 'His',
    'I': 'Ile',
    'L': 'Leu',
    'K': 'Lys',
    'M': 'Met',
    'F': 'Phe',
    'P': 'Pro',
    'S': 'Ser',
    'T': 'Thr',
    'W': 'Trp',
    'Y': 'Tyr',
    'V': 'Val'
}

# %%
new_df[['HGVSP', 'MUTATION_AA']] = data[[' HGVSP', ' MUTATION_AA']]

# %%
#extract wild-type and mutant amino acids and mutation position in 1-letter and 3-letter format
new_df['WT_AA_1'] = new_df['MUTATION_AA'].str[2]
new_df['WT_AA_3'] = new_df['WT_AA_1'].map(aa_mapping)

new_df['CODON_POSITION'] = new_df['MUTATION_AA'].str.extract('(\d+)')
new_df['CODON_POSITION'] = pd.to_numeric(new_df['CODON_POSITION'], errors='coerce')

new_df['MT_AA_1'] = new_df['MUTATION_AA'].str[-1]
new_df['MT_AA_3'] = new_df['MT_AA_1'].map(aa_mapping)

# %% [markdown]
# Add all your site and histology specific features now.

# %%
 new_df[['MUTATION_SOMATIC_STATUS', 'PRIMARY_SITE', 'PRIMARY_HISTOLOGY', 'SAMPLE_TYPE', 'TUMOUR_ORIGIN', 'GENOMIC_MUTATION_ID', 'PUBMED_PMID']] = data[[' MUTATION_SOMATIC_STATUS', ' PRIMARY_SITE', ' PRIMARY_HISTOLOGY', ' SAMPLE_TYPE', ' TUMOUR_ORIGIN', ' GENOMIC_MUTATION_ID', ' PUBMED_PMID']]

# %%
new_df['PRIMARY_SITE'] = new_df['PRIMARY_SITE'].str.replace('_', ' ')
new_df['PRIMARY_HISTOLOGY'] = new_df['PRIMARY_HISTOLOGY'].str.replace('_', ' ')

# %%
new_df
# Out:
#      GENE_NAME   ACCESSION_NUMBER   GENE_CDS_LENGTH            HGVSG  \
# 1       CDKN2A  ENST00000498124.1               504  9:g.21971110G>T
# 16      CDKN2A  ENST00000498124.1               504  9:g.21971171A>G
# 17      CDKN2A  ENST00000498124.1               504  9:g.21971135G>A
# 18      CDKN2A  ENST00000498124.1               504  9:g.21974742C>T
# 20      CDKN2A  ENST00000498124.1               504  9:g.21971203C>G
# ...        ...                ...               ...              ...
# 3700    CDKN2A  ENST00000498124.1               504  9:g.21971117G>A
# 3706    CDKN2A  ENST00000498124.1               504  9:g.21971109C>T
# 3711    CDKN2A  ENST00000498124.1               504  9:g.21970992G>T
# 3713    CDKN2A  ENST00000498124.1               504  9:g.21971108T>C
# 3715    CDKN2A  ENST00000498124.1               504  9:g.21970970A>G
#
#                            HGVSC  MUTATION_CDS  CDNA_POSITION MUTATION_EVENT  \
# 1     ENST00000498124.1:c.249C>A      c.249C>A            249            C>A
# 16    ENST00000498124.1:c.188T>C      c.188T>C            188            T>C
# 17    ENST00000498124.1:c.224C>T      c.224C>T            224            C>T
# 18     ENST00000498124.1:c.86G>A       c.86G>A             86            G>A
# 20    ENST00000498124.1:c.156G>C      c.156G>C            156            G>C
# ...                          ...           ...            ...            ...
# 3700  ENST00000498124.1:c.242C>T      c.242C>T            242            C>T
# 3706  ENST00000498124.1:c.250G>A      c.250G>A            250            G>A
# 3711  ENST00000498124.1:c.367C>A      c.367C>A            367            C>A
# 3713  ENST00000498124.1:c.251A>G      c.251A>G            251            A>G
# 3715  ENST00000498124.1:c.389T>C      c.389T>C            389            T>C
#
#      BASE_ALLELE MUTANT_ALLELE  ... CODON_POSITION MT_AA_1 MT_AA_3  \
# 1              C             A  ...             83       Q     Gln
# 16             T             C  ...             63       P     Pro
# 17             C             T  ...             75       L     Leu
# 18             G             A  ...             29       Q     Gln
# 20             G             C  ...             52       I     Ile
# ...          ...           ...  ...            ...     ...     ...
# 3700           C             T  ...             81       L     Leu
# 3706           G             A  ...             84       N     Asn
# 3711           C             A  ...            123       N     Asn
# 3713           A             G  ...             84       G     Gly
# 3715           T             C  ...            130       P     Pro
#
#         MUTATION_SOMATIC_STATUS               PRIMARY_SITE  \
# 1     Variant of unknown origin                     pleura
# 16    Variant of unknown origin                       skin
# 17    Variant of unknown origin                       lung
# 18    Variant of unknown origin  upper aerodigestive tract
# 20    Variant of unknown origin                     breast
# ...                         ...                        ...
# 3700  Confirmed somatic variant                       skin
# 3706  Confirmed somatic variant     central nervous system
# 3711  Confirmed somatic variant                       lung
# 3713  Confirmed somatic variant     central nervous system
# 3715  Confirmed somatic variant  upper aerodigestive tract
#
#                                      PRIMARY_HISTOLOGY           SAMPLE_TYPE  \
# 1                                         mesothelioma  surgery fresh/frozen
# 16                                  malignant melanoma         surgery - NOS
# 17                                           carcinoma         surgery-fixed
# 18                                           carcinoma         surgery-fixed
# 20                                           carcinoma             cell-line
# ...                                                ...                   ...
# 3700                                malignant melanoma         surgery-fixed
# 3706  primitive neuroectodermal tumour-medulloblastoma                    NS
# 3711                                         carcinoma         surgery-fixed
# 3713                                            glioma  surgery fresh/frozen
# 3715                                         carcinoma  surgery fresh/frozen
#
#      TUMOUR_ORIGIN GENOMIC_MUTATION_ID PUBMED_PMID
# 1          primary        COSV58684711  12117769.0
# 16      metastasis        COSV58716983  20703244.0
# 17      metastasis        COSV58688496  26164066.0
# 18              NS        COSV58704956  19690981.0
# 20              NS        COSV58687020  19593635.0
# ...            ...                 ...         ...
# 3700    metastasis        COSV58683884  28481359.0
# 3706            NS        COSV58683289         NaN
# 3711       primary        COSV58709909  28481359.0
# 3713            NS        COSV58688961  28263318.0
# 3715       primary        COSV58702833  19101490.0
#
# [1351 rows x 24 columns]

# %%
# distinct_primary_histology_values = new_df['PRIMARY_HISTOLOGY'].unique()

# print("Distinct Values in PRIMARY_HISTOLOGY column:")
# print()
# for value in distinct_primary_histology_values:
#     print(value)
    
    
distinct_primary_histology_values = new_df['PRIMARY_HISTOLOGY'].unique()

print("Counts of each distinct value in PRIMARY_HISTOLOGY column:")
print(new_df['PRIMARY_HISTOLOGY'].value_counts())
# Out:
# Counts of each distinct value in PRIMARY_HISTOLOGY column:
# carcinoma                                              982
# malignant melanoma                                     163
# other                                                   39
# lymphoid neoplasm                                       37
# glioma                                                  35
# haematopoietic neoplasm                                 24
# adnexal tumour                                          20
# meningioma                                               7
# gastrointestinal stromal tumour                          3
# germ cell tumour                                         3
# carcinoid-endocrine tumour                               3
# benign melanocytic nevus                                 3
# primitive neuroectodermal tumour-medulloblastoma         2
# mesothelioma                                             2
# pancreatic intraepithelial neoplasia (PanIN)             2
# sarcoma                                                  2
# malignant fibrous histiocytoma-pleomorphic sarcoma       2
# neuroblastoma                                            2
# adrenal cortical carcinoma                               2
# pheochromocytoma                                         2
# fibrosarcoma                                             2
# thymic carcinoma                                         1
# calcifying epithelial odontogenic tumour                 1
# Wilms tumour                                             1
# adenoma                                                  1
# malignant melanoma of soft parts-clear cell sarcoma      1
# fibroepithelial neoplasm                                 1
# in situ neoplasm                                         1
# rhabdomyosarcoma                                         1
# leiomyosarcoma                                           1
# NS                                                       1
# paraganglioma                                            1
# chondrosarcoma                                           1
# in situ epithelial neoplasm                              1
# low malignant potential (borderline) tumour              1
# Name: PRIMARY_HISTOLOGY, dtype: int64

# %%
cancer_type_mappings = {
    'mesothelioma': 'Other',
    'malignant melanoma': 'Skin Cancer',
    'carcinoma': 'Carcinoma',
    'lymphoid neoplasm': 'Lymphoma',
    'haematopoietic neoplasm': 'Leukemia',
    'adnexal tumour': 'Skin Cancer',
    'glioma': 'Brain Tumor',
    'gastrointestinal stromal tumour': 'Other',
    'fibrosarcoma': 'Sarcoma',
    'rhabdomyosarcoma': 'Sarcoma',
    'other': 'Other',
    'carcinoid-endocrine tumour': 'Other',
    'pheochromocytoma': 'Other',
    'meningioma': 'Brain Tumor',
    'malignant melanoma of soft parts-clear cell sarcoma': 'Sarcoma',
    'Wilms tumour': 'Other',
    'calcifying epithelial odontogenic tumour': 'Other',
    'low malignant potential (borderline) tumour': 'Other',
    'thymic carcinoma': 'Other',
    'sarcoma': 'Sarcoma',
    'primitive neuroectodermal tumour-medulloblastoma': 'Brain Tumor',
    'germ cell tumour': 'Other',
    'adenoma': 'Other',
    'benign melanocytic nevus': 'Skin Cancer',
    'fibroepithelial neoplasm': 'Other',
    'pancreatic intraepithelial neoplasia (PanIN)': 'Other',
    'in situ neoplasm': 'Other',
    'neuroblastoma': 'Brain Tumor',
    'leiomyosarcoma': 'Sarcoma',
    'NS': 'Other',
    'paraganglioma': 'Other',
    'malignant fibrous histiocytoma-pleomorphic sarcoma': 'Sarcoma',
    'chondrosarcoma': 'Other',
    'in situ epithelial neoplasm': 'Carcinoma',
    'adrenal cortical carcinoma': 'Other'
}

# %%
new_df['CANCER_TYPE'] = 'Other'  
new_df['CANCER_TYPE'] = new_df['PRIMARY_HISTOLOGY'].map(cancer_type_mappings)
print(new_df[['PRIMARY_HISTOLOGY', 'CANCER_TYPE']])
# Out:
#                                      PRIMARY_HISTOLOGY  CANCER_TYPE
# 1                                         mesothelioma        Other
# 16                                  malignant melanoma  Skin Cancer
# 17                                           carcinoma    Carcinoma
# 18                                           carcinoma    Carcinoma
# 20                                           carcinoma    Carcinoma
# ...                                                ...          ...
# 3700                                malignant melanoma  Skin Cancer
# 3706  primitive neuroectodermal tumour-medulloblastoma  Brain Tumor
# 3711                                         carcinoma    Carcinoma
# 3713                                            glioma  Brain Tumor
# 3715                                         carcinoma    Carcinoma
#
# [1351 rows x 2 columns]

# %%
distinct_cancers = new_df['CANCER_TYPE'].unique()

print("Distinct Values in CANCER_TYPE column:")
print(new_df['CANCER_TYPE'].value_counts())
# Out:
# Distinct Values in CANCER_TYPE column:
# Carcinoma      983
# Skin Cancer    186
# Other           66
# Brain Tumor     46
# Lymphoma        37
# Leukemia        24
# Sarcoma          9
# Name: CANCER_TYPE, dtype: int64

# %%
new_df.to_csv('filtered_df.csv', index=False)

# %% [markdown]
# Now we have our filtered file which we can use for analysis.
